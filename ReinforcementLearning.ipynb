# %% [markdown]
# Original code taken from [https://gist.github.com/EderSantana/c7222daa328f0e885093](https://gist.github.com/EderSantana/c7222daa328f0e885093)

# %% [markdown]
# # Installation
# To be able to run the animation below, make sure you have the latest version of matplotlib, by running `python3 -m pip install matplotlib --upgrade`

# %%
# %matplotlib inline
import json
import numpy as np
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
import matplotlib.animation
import IPython.display

# %% [markdown]
# ## Define the game environment and replay classes
# The idea in this Catch game is that there is fruit falling, and the user gets to move a basket so that they catch the fruit. If they catch it, they win and the game is over. If they miss it, they lose and the game is over. We are trying to teach the computer to play this game.

# %%
class Catch(object):
    def __init__(self, grid_size=10):
        '''
        Input: grid_size (length of the side of the canvas)
        
        Initializes internal state.
        '''
        self.grid_size = grid_size
        self.min_basket_center = 1
        self.max_basket_center = self.grid_size-2
        self.reset()
        self.fruits_caught = 0 
        self.best_score = 1

    def _update_state(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Moves basket according to action. Moves fruit down. Updates state to reflect these movements
        '''
        if action == 0:  # left
            movement = -1
        elif action == 1:  # stay
            movement = 0
        elif action == 2: # right
            movement = 1
        else:
            raise Exception('Invalid action {}'.format(action))
        fruit_x, fruit_y, basket_center = self.state
        # move the basket unless this would move it off the edge of the grid
        new_basket_center = min(max(self.min_basket_center, basket_center + movement), self.max_basket_center)
        # move fruit down
        fruit_y += 1
        out = np.asarray([fruit_x, fruit_y, new_basket_center])
        self.state = out

    def _draw_state(self):
        '''
        Returns a 2D numpy array with 1s (white squares) at the locations of the fruit and basket and
        0s (black squares) everywhere else.
        '''
        im_size = (self.grid_size, self.grid_size)
        canvas = np.zeros(im_size)
        
        fruit_x, fruit_y, basket_center = self.state
        canvas[fruit_y, fruit_x] = 1  # draw fruit
        canvas[-1, basket_center-1:basket_center + 2] = 1  # draw 3-pixel basket
        return canvas
    #     Code for Exercise 3
    # def _get_reward(self):
    
    #     '''
    #     Returns 1 if the fruit was caught, -1 if it was dropped, and 0 if it is still in the air.
    #     '''
    #     fruit_x, fruit_y, basket_center = self.state
    #     if fruit_y == self.grid_size-1:
    #         if abs(fruit_x - basket_center) <= 1:
    #             return -1 # it caught the fruit
    #         else:
    #             return 1 # it dropped the fruit
    #     else:
    #         return 0 # the fruit is still in the air
    def _get_reward(self):
        '''
        Returns 1 if the fruit was caught, -1 if it was dropped, and 0 if it is still in the air.
        '''
        #code for exercise 4
        fruit_x, fruit_y, basket_center = self.state
        best_score = self.best_score
        if fruit_y == self.grid_size-1:
            fruits_caught = self.fruits_caught
            if abs(fruit_x - basket_center) <= 1:
                self.fruits_caught += 1
                if (fruits_caught >= 20):
                    self.fruits_caught = 0
                    self.best_score = fruits_caught
                    return 1
                self.reset()
                return 0 #game should keep going
            else:
                self.fruits_caught = 0
                self.best_score = fruits_caught
                #Adjusting reward slightly so 0 doesn't get returned
                if fruits_caught == best_score-1:
                    return -0.01
                return max(-1, (fruits_caught+1 - best_score) / 2)
                #return -1 # it dropped the fruit
        else:
            return 0 # the fruit is still in the air
    def observe(self):
        '''
        Returns the current canvas, as a 1D array.
        '''
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Returns:
            current canvas (as a 1D array)
            reward received after this action
            True if game is over and False otherwise
        '''
        self._update_state(action)
        observation = self.observe()
        reward = self._get_reward()
        game_over = (reward != 0) # if the reward is zero, the fruit is still in the air
        return observation, reward, game_over

    def reset(self):
        '''
        Updates internal state
            fruit in a random column in the top row
            basket center in a random column
        '''
        fruit_x = random.randint(0, self.grid_size-1)
        fruit_y = 0
        basket_center = random.randint(self.min_basket_center, self.max_basket_center)
        self.state = np.asarray([fruit_x, fruit_y, basket_center])


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        '''
        Input:
            states: [starting_observation, action_taken, reward_received, new_observation]
            game_over: boolean
        Add the states and game over to the internal memory array. If the array is longer than
        self.max_memory, drop the oldest memory
        '''
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        '''
        Randomly chooses batch_size memories, possibly repeating.
        For each of these memories, updates the models current best guesses about the value of taking a
            certain action from the starting state, based on the reward received and the model's current
            estimate of how valuable the new state is.
        '''
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1] # the number of possible actions
        env_dim = self.memory[0][0][0].shape[1] # the number of pixels in the image
        input_size = min(len_memory, batch_size)
        inputs = np.zeros((input_size, env_dim))
        targets = np.zeros((input_size, num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory, size=input_size)):
            starting_observation, action_taken, reward_received, new_observation = self.memory[idx][0]
            game_over = self.memory[idx][1]

            # Set the input to the state that was observed in the game before an action was taken
            inputs[i] = starting_observation[0]
            
            # Start with the model's current best guesses about the value of taking each action from this state
            #convolutional
            #targets[i] = model.predict(starting_observation.reshape(-1,10,10,1))[0]
            targets[i] = model.predict(starting_observation)[0]
            
            # Now we need to update the value of the action that was taken                      
            if game_over: 
                # if the game is over, give the actual reward received
                targets[i, action_taken] = reward_received
            else:
                # if the game is not over, give the reward received (always zero in this particular game)
                # plus the maximum reward predicted for state we got to by taking this action (with a discount)
                #convolutional
                #Q_sa = np.max(model.predict(new_observation.reshape(-1,10,10,1))[0])
                Q_sa = np.max(model.predict(new_observation)[0])
                targets[i, action_taken] = reward_received + self.discount * Q_sa
        return inputs, targets

# %% [markdown]
# ##  Functions for creating, training, and visualizing the model

# %%
# parameters
epsilon = .1  # probability of exploration (choosing a random action instead of the current best one)
num_actions = 3  # [move_left, stay, move_right]
max_memory = 500
hidden_size = 100
batch_size = 50
grid_size = 10
print_freq = 10


def build_model():
    '''
     Returns three initialized objects: the model, the environment, and the replay.
    '''
    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    # Convolutional Model for exercise #2
    # The model was very bad before I changed the optimizer
    
    # model.add(Conv2D(input_shape=(grid_size, grid_size, 1),
    #              filters=32, kernel_size=5, strides=1, padding='same', activation='tanh'))
    # model.add(Conv2D(input_shape=(grid_size, grid_size, 1),
    #              filters=32, kernel_size=5, strides=1, padding='same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=(2,2)))
    # model.add(Dropout(0.15))
    # model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='tanh'))
    # model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
    # model.add(Flatten())
    # model.add(Dense(units=32, activation='relu'))
    # model.add(Dense(units=num_actions, activation='relu'))
    # model.add(RMSprop(), "mse")
    model.compile(Adam(), "mse")

    # Define environment/game
    env = Catch(grid_size)

    # Initialize experience replay object
    exp_replay = ExperienceReplay(max_memory=max_memory)
    
    return model, env, exp_replay

def take_step(exp_replay, model, starting_observation):
    # get next action
    if np.random.rand() <= epsilon:
        # epsilon of the time, we just choose randomly
        action = np.random.randint(0, num_actions, size=1)
    else:
        # find which action the model currently thinks is best from this state
        #convolutional
        #q = model.predict(starting_observation.reshape(-1,10,10,1))
        q = model.predict(starting_observation)
        action = np.argmax(q[0])

    # apply action, get rewards and new state
    new_observation, reward, game_over = env.act(action)

    # store experience
    exp_replay.remember([starting_observation, action, reward, new_observation], game_over)

    return new_observation, reward, game_over
    

def train_model(model, env, exp_replay, num_episodes, pretrain_episodes=100):
    '''
    Inputs:
        model, env, and exp_replay objects as returned by build_model
        num_episodes: integer, the number of episodes that should be rolled out for training
    '''
    for episode in range(pretrain_episodes):
        env.reset()
        game_over = False
        # get initial input
        starting_observation = env.observe()

        while not game_over:
            starting_observation, reward, game_over = \
                take_step(exp_replay, model, starting_observation)
    last_total_reward = 0
    total_reward = 0
    for episode in range(1, num_episodes+1):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        starting_observation = env.observe()

        while not game_over:
            starting_observation, reward, game_over = \
                take_step(exp_replay, model, starting_observation)
            total_reward += reward
            
        # get data updated based on the stored experiences
        inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

        # train model on the updated data
        #convolutional
        #loss += model.train_on_batch(inputs.reshape(-1,10,10,1), targets)          
        loss += model.train_on_batch(inputs, targets)  

        # Print update from this episode
        if episode % print_freq == 0:
            print("Episodes {:04d}-{:04d}/{:04d} | Loss {:.4f} | Total Reward {} | Change in Reward {}".format(
                episode - print_freq + 1, episode, num_episodes, loss, total_reward, total_reward - last_total_reward))
            last_total_reward = total_reward
            total_reward = 0



def create_animation(model, env, num_games):
    '''
    Inputs:
        model and env objects as returned from build_model
        num_games: integer, the number of games to be included in the animation
        
    Returns: a matplotlib animation object
    '''
    # Animation code from 
    # https://matplotlib.org/examples/animation/dynamic_image.html
    # https://stackoverflow.com/questions/35532498/animation-in-ipython-notebook/46878531#46878531
    
    # First, play the games and collect all of the images for each observed state
    observations = []
    total_reward = 0
    #for _ in range(1):
    for _ in range(num_games):
        env.reset()
        observation = env.observe()
        observations.append(observation)
        game_over = False
        while game_over == False:
            #observation needs to be reshaped for convolutional layer
            #q = model.predict(observation.reshape(-1,10,10,1))
            #normal
            q = model.predict([observation])
            action = np.argmax(q[0])
            
            # apply action, get rewards and new state
            observation, reward, game_over = env.act(action)
            observations.append(observation)
            total_reward += reward
            
    fig = plt.figure()
    image = plt.imshow(np.zeros((grid_size, grid_size)),interpolation='none', cmap='gray', animated=True, vmin=0, vmax=1)
    print('Total Reward: {}'.format(total_reward))
    
    def animate(observation):
        image.set_array(observation.reshape((grid_size, grid_size)))
        return [image]
   
    animation = matplotlib.animation.FuncAnimation(fig, animate, frames=observations, blit=True, )
    return animation

# %% [markdown]
# ## Let's create our model and game environment and see how it does before training

# %%
model, env, exp_replay = build_model()

# %%
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())

# %% [markdown]
# ## Now train the model and see how much better it is at catching the fruit

# %%
#Original network
train_model(model, env, exp_replay, num_episodes=1000)
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Episodes 0001-0010/1000 | Loss 0.0324 | Total Reward -8 | Change in Reward -8
# Episodes 0011-0020/1000 | Loss 0.0301 | Total Reward 0 | Change in Reward 8
# Episodes 0021-0030/1000 | Loss 0.0101 | Total Reward -4 | Change in Reward -4
# Episodes 0031-0040/1000 | Loss 0.0241 | Total Reward -2 | Change in Reward 2
# Episodes 0041-0050/1000 | Loss 0.0512 | Total Reward -4 | Change in Reward -2
# Episodes 0051-0060/1000 | Loss 0.0222 | Total Reward -4 | Change in Reward 0
# Episodes 0061-0070/1000 | Loss 0.0238 | Total Reward 0 | Change in Reward 4
# Episodes 0071-0080/1000 | Loss 0.0171 | Total Reward -4 | Change in Reward -4
# Episodes 0081-0090/1000 | Loss 0.0273 | Total Reward 0 | Change in Reward 4
# Episodes 0091-0100/1000 | Loss 0.0251 | Total Reward -10 | Change in Reward -10
# Episodes 0101-0110/1000 | Loss 0.0161 | Total Reward -4 | Change in Reward 6
# Episodes 0111-0120/1000 | Loss 0.0089 | Total Reward -4 | Change in Reward 0
# Episodes 0121-0130/1000 | Loss 0.0146 | Total Reward -2 | Change in Reward 2
# Episodes 0131-0140/1000 | Loss 0.0157 | Total Reward -4 | Change in Reward -2
# Episodes 0141-0150/1000 | Loss 0.0153 | Total Reward 0 | Change in Reward 4
# Episodes 0151-0160/1000 | Loss 0.0325 | Total Reward -2 | Change in Reward -2
# Episodes 0161-0170/1000 | Loss 0.0301 | Total Reward -6 | Change in Reward -4
# Episodes 0171-0180/1000 | Loss 0.0352 | Total Reward 8 | Change in Reward 14
# Episodes 0181-0190/1000 | Loss 0.0175 | Total Reward 0 | Change in Reward -8
# Episodes 0191-0200/1000 | Loss 0.0232 | Total Reward 0 | Change in Reward 0
# Episodes 0201-0210/1000 | Loss 0.0290 | Total Reward 6 | Change in Reward 6
# Episodes 0211-0220/1000 | Loss 0.0132 | Total Reward -4 | Change in Reward -10
# Episodes 0221-0230/1000 | Loss 0.0040 | Total Reward 0 | Change in Reward 4
# Episodes 0231-0240/1000 | Loss 0.0093 | Total Reward 2 | Change in Reward 2
# Episodes 0241-0250/1000 | Loss 0.0122 | Total Reward -2 | Change in Reward -4
# Episodes 0251-0260/1000 | Loss 0.0111 | Total Reward 0 | Change in Reward 2
# Episodes 0261-0270/1000 | Loss 0.0179 | Total Reward -2 | Change in Reward -2
# Episodes 0271-0280/1000 | Loss 0.0057 | Total Reward -6 | Change in Reward -4
# Episodes 0281-0290/1000 | Loss 0.0276 | Total Reward 0 | Change in Reward 6
# Episodes 0291-0300/1000 | Loss 0.0227 | Total Reward 0 | Change in Reward 0
# Episodes 0301-0310/1000 | Loss 0.0071 | Total Reward 2 | Change in Reward 2
# Episodes 0311-0320/1000 | Loss 0.0167 | Total Reward 4 | Change in Reward 2
# Episodes 0321-0330/1000 | Loss 0.0283 | Total Reward 0 | Change in Reward -4
# Episodes 0331-0340/1000 | Loss 0.0087 | Total Reward 0 | Change in Reward 0
# Episodes 0341-0350/1000 | Loss 0.0107 | Total Reward -6 | Change in Reward -6
# Episodes 0351-0360/1000 | Loss 0.0063 | Total Reward 8 | Change in Reward 14
# Episodes 0361-0370/1000 | Loss 0.0195 | Total Reward 0 | Change in Reward -8
# Episodes 0371-0380/1000 | Loss 0.0120 | Total Reward 6 | Change in Reward 6
# Episodes 0381-0390/1000 | Loss 0.0086 | Total Reward 0 | Change in Reward -6
# Episodes 0391-0400/1000 | Loss 0.0190 | Total Reward 0 | Change in Reward 0
# Episodes 0401-0410/1000 | Loss 0.0061 | Total Reward 6 | Change in Reward 6
# Episodes 0411-0420/1000 | Loss 0.0103 | Total Reward 2 | Change in Reward -4
# Episodes 0421-0430/1000 | Loss 0.0073 | Total Reward 6 | Change in Reward 4
# Episodes 0431-0440/1000 | Loss 0.0078 | Total Reward 8 | Change in Reward 2
# Episodes 0441-0450/1000 | Loss 0.0102 | Total Reward 8 | Change in Reward 0
# Episodes 0451-0460/1000 | Loss 0.0034 | Total Reward 10 | Change in Reward 2
# Episodes 0461-0470/1000 | Loss 0.0045 | Total Reward 8 | Change in Reward -2
# Episodes 0471-0480/1000 | Loss 0.0130 | Total Reward 10 | Change in Reward 2
# Episodes 0481-0490/1000 | Loss 0.0039 | Total Reward 10 | Change in Reward 0
# Episodes 0491-0500/1000 | Loss 0.0044 | Total Reward 4 | Change in Reward -6
# Episodes 0501-0510/1000 | Loss 0.0028 | Total Reward 10 | Change in Reward 6
# Episodes 0511-0520/1000 | Loss 0.0056 | Total Reward 8 | Change in Reward -2
# Episodes 0521-0530/1000 | Loss 0.0027 | Total Reward 10 | Change in Reward 2
# Episodes 0531-0540/1000 | Loss 0.0036 | Total Reward 8 | Change in Reward -2
# Episodes 0541-0550/1000 | Loss 0.0021 | Total Reward 6 | Change in Reward -2
# Episodes 0551-0560/1000 | Loss 0.0021 | Total Reward 10 | Change in Reward 4
# Episodes 0561-0570/1000 | Loss 0.0119 | Total Reward 8 | Change in Reward -2
# Episodes 0571-0580/1000 | Loss 0.0027 | Total Reward 10 | Change in Reward 2
# Episodes 0581-0590/1000 | Loss 0.0060 | Total Reward 10 | Change in Reward 0
# Episodes 0591-0600/1000 | Loss 0.0028 | Total Reward 10 | Change in Reward 0
# Episodes 0601-0610/1000 | Loss 0.0013 | Total Reward 10 | Change in Reward 0
# Episodes 0611-0620/1000 | Loss 0.0017 | Total Reward 8 | Change in Reward -2
# Episodes 0621-0630/1000 | Loss 0.0202 | Total Reward 10 | Change in Reward 2
# Episodes 0631-0640/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0641-0650/1000 | Loss 0.0017 | Total Reward 10 | Change in Reward 0
# Episodes 0651-0660/1000 | Loss 0.0011 | Total Reward 8 | Change in Reward -2
# Episodes 0661-0670/1000 | Loss 0.0015 | Total Reward 8 | Change in Reward 0
# Episodes 0671-0680/1000 | Loss 0.0021 | Total Reward 8 | Change in Reward 0
# Episodes 0681-0690/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 2
# Episodes 0691-0700/1000 | Loss 0.0038 | Total Reward 8 | Change in Reward -2
# Episodes 0701-0710/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 2
# Episodes 0711-0720/1000 | Loss 0.0024 | Total Reward 10 | Change in Reward 0
# Episodes 0721-0730/1000 | Loss 0.0020 | Total Reward 10 | Change in Reward 0
# Episodes 0731-0740/1000 | Loss 0.0025 | Total Reward 8 | Change in Reward -2
# Episodes 0741-0750/1000 | Loss 0.0061 | Total Reward 8 | Change in Reward 0
# Episodes 0751-0760/1000 | Loss 0.0034 | Total Reward 10 | Change in Reward 2
# Episodes 0761-0770/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 0
# Episodes 0771-0780/1000 | Loss 0.0013 | Total Reward 8 | Change in Reward -2
# Episodes 0781-0790/1000 | Loss 0.0019 | Total Reward 10 | Change in Reward 2
# Episodes 0791-0800/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0801-0810/1000 | Loss 0.0010 | Total Reward 8 | Change in Reward -2
# Episodes 0811-0820/1000 | Loss 0.0016 | Total Reward 10 | Change in Reward 2
# Episodes 0821-0830/1000 | Loss 0.0049 | Total Reward 10 | Change in Reward 0
# Episodes 0831-0840/1000 | Loss 0.0021 | Total Reward 10 | Change in Reward 0
# Episodes 0841-0850/1000 | Loss 0.0016 | Total Reward 8 | Change in Reward -2
# Episodes 0851-0860/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 2
# Episodes 0861-0870/1000 | Loss 0.0022 | Total Reward 8 | Change in Reward -2
# Episodes 0871-0880/1000 | Loss 0.0163 | Total Reward 10 | Change in Reward 2
# Episodes 0881-0890/1000 | Loss 0.0020 | Total Reward 10 | Change in Reward 0
# Episodes 0891-0900/1000 | Loss 0.0010 | Total Reward 10 | Change in Reward 0
# Episodes 0901-0910/1000 | Loss 0.0012 | Total Reward 6 | Change in Reward -4
# Episodes 0911-0920/1000 | Loss 0.0023 | Total Reward 10 | Change in Reward 4
# Episodes 0921-0930/1000 | Loss 0.0111 | Total Reward 10 | Change in Reward 0
# Episodes 0931-0940/1000 | Loss 0.0026 | Total Reward 10 | Change in Reward 0
# Episodes 0941-0950/1000 | Loss 0.0010 | Total Reward 8 | Change in Reward -2
# Episodes 0951-0960/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 2
# Episodes 0961-0970/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0971-0980/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 0
# Episodes 0981-0990/1000 | Loss 0.0014 | Total Reward 8 | Change in Reward -2
# Episodes 0991-1000/1000 | Loss 0.0013 | Total Reward 10 | Change in Reward 2
# Total Reward: 10
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img78bb7097d9a24a528a3b79d01caba202">
#   <div class="anim-controls">
#     <input id="_anim_slider78bb7097d9a24a528a3b79d01caba202" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim78bb7097d9a24a528a3b79d01caba202.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim78bb7097d9a24a528a3b79d01caba202.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select78bb7097d9a24a528a3b79d01caba202" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_78bb7097d9a24a528a3b79d01caba202"
#              >
#       <label for="_anim_radio1_78bb7097d9a24a528a3b79d01caba202">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_78bb7097d9a24a528a3b79d01caba202"
#              checked>
#       <label for="_anim_radio2_78bb7097d9a24a528a3b79d01caba202">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_78bb7097d9a24a528a3b79d01caba202"
#              >
#       <label for="_anim_radio3_78bb7097d9a24a528a3b79d01caba202">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img78bb7097d9a24a528a3b79d01caba202";
#     var slider_id = "_anim_slider78bb7097d9a24a528a3b79d01caba202";
#     var loop_select_id = "_anim_loop_select78bb7097d9a24a528a3b79d01caba202";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANCklEQVR4nO3cP2hW99/H4U98oouobTFijIqKoEkU\
# TIykSwc7qIg4aAbFQlFDQBwUcenWyYq0+Kd2yeKgYIYOtSg6aClt/YOk2oKEitAETLRgQW01Skx6\
# /4YH2odH08qvxnM+el1b8NzxDeL3xTn3nVRVKpVKAEAy44oeAAD/DQEDICUBAyAlAQMgJQEDICUB\
# AyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQED\
# ICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMg\
# peqiB/DvTZ06NebMmfPCv+/333//wr8nZFWpVIqewP8jYK+AOXPmRHd39wv/vlVVVS/8ewK8KB4h\
# ApCSgAGQkoABkJKAAZCSgJXQm

# %% [markdown]
# # Possible Exercises:
# 1. Add a validation function, to make it easier to assess models.
# 1. We've been looking at convolutional neural networks for image processing. Try changing the model to use convolutional layers. Does this seem to work any better?
# 1. Change the code so that the basket is trying to avoid getting hit by the fruit.
# 1. Change the code so the game keeps going until the basket misses the fruit. (To test that this is working, you may want to change the number of games in the animation to 1.) How should this change the rewards that the model gets?
# 1. Change the game to something entirely different.
# 1. Try changing how the training works (for instance, changing the discount rate or having the model always choose the action randomly weighted by the action values). Keep notes on what you observe as to how this changes the model performance.

# %% [markdown]
# Using RMSprop, the convolutional layers made the model train much faster. However, when using ADAM, the convolutional layers could not train.

# %%
model, env, exp_replay = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 10, 10, 32)        832
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 10, 10, 32)        25632
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 5, 5, 64)          18496
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                51232
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 133,219
# Trainable params: 133,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Total Reward: -6
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5ab017374c664be08c66d9218d0509e4">
#   <div class="anim-controls">
#     <input id="_anim_slider5ab017374c664be08c66d9218d0509e4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5ab017374c664be08c66d9218d0509e4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim5ab017374c664be08c66d9218d0509e4.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select5ab017374c664be08c66d9218d0509e4" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5ab017374c664be08c66d9218d0509e4"
#              >
#       <label for="_anim_radio1_5ab017374c664be08c66d9218d0509e4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5ab017374c664be08c66d9218d0509e4"
#              checked>
#       <label for="_anim_radio2_5ab017374c664be08c66d9218d0509e4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5ab017374c664be08c66d9218d0509e4"
#              >
#       <label for="_anim_radio3_5ab017374c664be08c66d9218d0509e4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5ab017374c664be08c66d9218d0509e4";
#     var slider_id = "_anim_slider5ab017374c664be08c66d9218d0509e4";
#     var loop_select_id = "_anim_loop_select5ab017374c664be08c66d9218d0509e4";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAM/UlEQVR4nO3cX2hXhf/H8ff8TW9ErWji3BSVkW1T\
# cHNiN13YhYqIF7oLxSDUMZAuFPGmu65sSOGf7GY3Xii4iy4ylIQ0ovIPsrRAJBHaYJsGBWrplLn1\
# +V38oH78dCXffuuct3s87j54PvMFc+fJOZ/jqiqVSiUAIJkpRQ8AgP+EgAGQkoABkJKAAZCSgAGQ\
# koABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCS\
# gAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKA\
# AZBSddED+Oeqqqom5OsuX758Qr7ut99+OyFfFyZSpVIpegL/R1XFdyW9iQrYRP3TmKi9MJGcKsvH\
# LUQAUhIwAFISMABSEjAAUhKwE

# %%
#convolutional network
train_model(model, env, exp_replay, num_episodes=1000)
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Episodes 0001-0010/1000 | Loss 0.0531 | Total Reward 0 | Change in Reward 0
# Episodes 0011-0020/1000 | Loss 0.0397 | Total Reward -2 | Change in Reward -2
# Episodes 0021-0030/1000 | Loss 0.0341 | Total Reward -2 | Change in Reward 0
# Episodes 0031-0040/1000 | Loss 0.0282 | Total Reward -4 | Change in Reward -2
# Episodes 0041-0050/1000 | Loss 0.0282 | Total Reward 2 | Change in Reward 6
# Episodes 0051-0060/1000 | Loss 0.0078 | Total Reward 6 | Change in Reward 4
# Episodes 0061-0070/1000 | Loss 0.0374 | Total Reward 8 | Change in Reward 2
# Episodes 0071-0080/1000 | Loss 0.0090 | Total Reward 4 | Change in Reward -4
# Episodes 0081-0090/1000 | Loss 0.0152 | Total Reward 2 | Change in Reward -2
# Episodes 0091-0100/1000 | Loss 0.0137 | Total Reward -4 | Change in Reward -6
# Episodes 0101-0110/1000 | Loss 0.0644 | Total Reward 6 | Change in Reward 10
# Episodes 0111-0120/1000 | Loss 0.0212 | Total Reward 6 | Change in Reward 0
# Episodes 0121-0130/1000 | Loss 0.0438 | Total Reward 0 | Change in Reward -6
# Episodes 0131-0140/1000 | Loss 0.0151 | Total Reward 6 | Change in Reward 6
# Episodes 0141-0150/1000 | Loss 0.0508 | Total Reward 2 | Change in Reward -4
# Episodes 0151-0160/1000 | Loss 0.0272 | Total Reward 6 | Change in Reward 4
# Episodes 0161-0170/1000 | Loss 0.0209 | Total Reward 6 | Change in Reward 0
# Episodes 0171-0180/1000 | Loss 0.0259 | Total Reward 6 | Change in Reward 0
# Episodes 0181-0190/1000 | Loss 0.0048 | Total Reward 4 | Change in Reward -2
# Episodes 0191-0200/1000 | Loss 0.0182 | Total Reward 8 | Change in Reward 4
# Episodes 0201-0210/1000 | Loss 0.0157 | Total Reward 8 | Change in Reward 0
# Episodes 0211-0220/1000 | Loss 0.0150 | Total Reward 10 | Change in Reward 2
# Episodes 0221-0230/1000 | Loss 0.0201 | Total Reward 4 | Change in Reward -6
# Episodes 0231-0240/1000 | Loss 0.0028 | Total Reward 8 | Change in Reward 4
# Episodes 0241-0250/1000 | Loss 0.0026 | Total Reward 8 | Change in Reward 0
# Episodes 0251-0260/1000 | Loss 0.0102 | Total Reward 6 | Change in Reward -2
# Episodes 0261-0270/1000 | Loss 0.0074 | Total Reward 10 | Change in Reward 4
# Episodes 0271-0280/1000 | Loss 0.0172 | Total Reward 10 | Change in Reward 0
# Episodes 0281-0290/1000 | Loss 0.0195 | Total Reward 4 | Change in Reward -6
# Episodes 0291-0300/1000 | Loss 0.0140 | Total Reward 8 | Change in Reward 4
# Episodes 0301-0310/1000 | Loss 0.0034 | Total Reward 10 | Change in Reward 2
# Episodes 0311-0320/1000 | Loss 0.0034 | Total Reward 10 | Change in Reward 0
# Episodes 0321-0330/1000 | Loss 0.0034 | Total Reward 10 | Change in Reward 0
# Episodes 0331-0340/1000 | Loss 0.0029 | Total Reward 10 | Change in Reward 0
# Episodes 0341-0350/1000 | Loss 0.0032 | Total Reward 10 | Change in Reward 0
# Episodes 0351-0360/1000 | Loss 0.0009 | Total Reward 10 | Change in Reward 0
# Episodes 0361-0370/1000 | Loss 0.0029 | Total Reward 10 | Change in Reward 0
# Episodes 0371-0380/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0381-0390/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0391-0400/1000 | Loss 0.0021 | Total Reward 8 | Change in Reward -2
# Episodes 0401-0410/1000 | Loss 0.0041 | Total Reward 8 | Change in Reward 0
# Episodes 0411-0420/1000 | Loss 0.0027 | Total Reward 8 | Change in Reward 0
# Episodes 0421-0430/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 2
# Episodes 0431-0440/1000 | Loss 0.0183 | Total Reward 10 | Change in Reward 0
# Episodes 0441-0450/1000 | Loss 0.0018 | Total Reward 8 | Change in Reward -2
# Episodes 0451-0460/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 2
# Episodes 0461-0470/1000 | Loss 0.0042 | Total Reward 10 | Change in Reward 0
# Episodes 0471-0480/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 0
# Episodes 0481-0490/1000 | Loss 0.0016 | Total Reward 10 | Change in Reward 0
# Episodes 0491-0500/1000 | Loss 0.0019 | Total Reward 8 | Change in Reward -2
# Episodes 0501-0510/1000 | Loss 0.0027 | Total Reward 10 | Change in Reward 2
# Episodes 0511-0520/1000 | Loss 0.0188 | Total Reward 6 | Change in Reward -4
# Episodes 0521-0530/1000 | Loss 0.0142 | Total Reward 6 | Change in Reward 0
# Episodes 0531-0540/1000 | Loss 0.0134 | Total Reward 10 | Change in Reward 4
# Episodes 0541-0550/1000 | Loss 0.0050 | Total Reward 10 | Change in Reward 0
# Episodes 0551-0560/1000 | Loss 0.0028 | Total Reward 8 | Change in Reward -2
# Episodes 0561-0570/1000 | Loss 0.0096 | Total Reward 10 | Change in Reward 2
# Episodes 0571-0580/1000 | Loss 0.0017 | Total Reward 10 | Change in Reward 0
# Episodes 0581-0590/1000 | Loss 0.0025 | Total Reward 10 | Change in Reward 0
# Episodes 0591-0600/1000 | Loss 0.0010 | Total Reward 10 | Change in Reward 0
# Episodes 0601-0610/1000 | Loss 0.0086 | Total Reward 10 | Change in Reward 0
# Episodes 0611-0620/1000 | Loss 0.0073 | Total Reward 10 | Change in Reward 0
# Episodes 0621-0630/1000 | Loss 0.0013 | Total Reward 8 | Change in Reward -2
# Episodes 0631-0640/1000 | Loss 0.0027 | Total Reward 8 | Change in Reward 0
# Episodes 0641-0650/1000 | Loss 0.0017 | Total Reward 6 | Change in Reward -2
# Episodes 0651-0660/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 4
# Episodes 0661-0670/1000 | Loss 0.0103 | Total Reward 8 | Change in Reward -2
# Episodes 0671-0680/1000 | Loss 0.0085 | Total Reward 10 | Change in Reward 2
# Episodes 0681-0690/1000 | Loss 0.0043 | Total Reward 8 | Change in Reward -2
# Episodes 0691-0700/1000 | Loss 0.0016 | Total Reward 8 | Change in Reward 0
# Episodes 0701-0710/1000 | Loss 0.0021 | Total Reward 10 | Change in Reward 2
# Episodes 0711-0720/1000 | Loss 0.0182 | Total Reward 4 | Change in Reward -6
# Episodes 0721-0730/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 6
# Episodes 0731-0740/1000 | Loss 0.0030 | Total Reward 10 | Change in Reward 0
# Episodes 0741-0750/1000 | Loss 0.0014 | Total Reward 10 | Change in Reward 0
# Episodes 0751-0760/1000 | Loss 0.0024 | Total Reward 10 | Change in Reward 0
# Episodes 0761-0770/1000 | Loss 0.0007 | Total Reward 10 | Change in Reward 0
# Episodes 0771-0780/1000 | Loss 0.0025 | Total Reward 10 | Change in Reward 0
# Episodes 0781-0790/1000 | Loss 0.0015 | Total Reward 10 | Change in Reward 0
# Episodes 0791-0800/1000 | Loss 0.0097 | Total Reward 8 | Change in Reward -2
# Episodes 0801-0810/1000 | Loss 0.0054 | Total Reward 8 | Change in Reward 0
# Episodes 0811-0820/1000 | Loss 0.0082 | Total Reward 4 | Change in Reward -4
# Episodes 0821-0830/1000 | Loss 0.0145 | Total Reward 4 | Change in Reward 0
# Episodes 0831-0840/1000 | Loss 0.0025 | Total Reward 10 | Change in Reward 6
# Episodes 0841-0850/1000 | Loss 0.0150 | Total Reward 10 | Change in Reward 0
# Episodes 0851-0860/1000 | Loss 0.0027 | Total Reward 10 | Change in Reward 0
# Episodes 0861-0870/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0871-0880/1000 | Loss 0.0083 | Total Reward 8 | Change in Reward -2
# Episodes 0881-0890/1000 | Loss 0.0017 | Total Reward 8 | Change in Reward 0
# Episodes 0891-0900/1000 | Loss 0.0043 | Total Reward 10 | Change in Reward 2
# Episodes 0901-0910/1000 | Loss 0.0020 | Total Reward 10 | Change in Reward 0
# Episodes 0911-0920/1000 | Loss 0.0007 | Total Reward 8 | Change in Reward -2
# Episodes 0921-0930/1000 | Loss 0.0017 | Total Reward 10 | Change in Reward 2
# Episodes 0931-0940/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 0
# Episodes 0941-0950/1000 | Loss 0.0009 | Total Reward 10 | Change in Reward 0
# Episodes 0951-0960/1000 | Loss 0.0010 | Total Reward 8 | Change in Reward -2
# Episodes 0961-0970/1000 | Loss 0.0011 | Total Reward 8 | Change in Reward 0
# Episodes 0971-0980/1000 | Loss 0.0011 | Total Reward 8 | Change in Reward 0
# Episodes 0981-0990/1000 | Loss 0.0013 | Total Reward 8 | Change in Reward 0
# Episodes 0991-1000/1000 | Loss 0.0010 | Total Reward 6 | Change in Reward -2
# Total Reward: 8
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd2892db43cb54c2694976684ec2af5ab">
#   <div class="anim-controls">
#     <input id="_anim_sliderd2892db43cb54c2694976684ec2af5ab" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd2892db43cb54c2694976684ec2af5ab.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd2892db43cb54c2694976684ec2af5ab.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd2892db43cb54c2694976684ec2af5ab" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d2892db43cb54c2694976684ec2af5ab"
#              >
#       <label for="_anim_radio1_d2892db43cb54c2694976684ec2af5ab">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d2892db43cb54c2694976684ec2af5ab"
#              checked>
#       <label for="_anim_radio2_d2892db43cb54c2694976684ec2af5ab">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d2892db43cb54c2694976684ec2af5ab"
#              >
#       <label for="_anim_radio3_d2892db43cb54c2694976684ec2af5ab">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd2892db43cb54c2694976684ec2af5ab";
#     var slider_id = "_anim_sliderd2892db43cb54c2694976684ec2af5ab";
#     var loop_select_id = "_anim_loop_selectd2892db43cb54c2694976684ec2af5ab";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANA0lEQVR4nO3cX2hXhf/H8ff8TW9ErfhOnJuiIuk2\
# BTcn66YLu1AR8UJ3oRiEOgbShSLedNeViRT+yW5244WCu+giQ0lIIyr/IEsLRBKhDbZpUKCWTplb\
# n+/Fj+rHT1fy7bvOebvH4+6D56MvmDtPzvmcrapSqVQCAJKZVPQAAPhPCBgAKQkYACkJGAApCRgA\
# KQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAAp\
# CRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJ\
# GAApVRc9gL+vqqqq6AmUxPLly8fl7/3666/H5e/NpFKpFD2B/6eq4quSnoDxm/H6dvZ/TMDKyC1E\
# AFISMABSEjAAUhIwAFISsBI6c

# %% [markdown]
# 3.

# %%
#Avoiding the fruit
#Interestingly enough, the dense neural network seemed to work better for this 
#than the convolutional network
model_drop, env, exp_replay = build_model()
model_drop.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 20,503
# Trainable params: 20,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
animation = create_animation(model_drop, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Total Reward: 2
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc8ed378e1d08448897c99ab759ba840e">
#   <div class="anim-controls">
#     <input id="_anim_sliderc8ed378e1d08448897c99ab759ba840e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc8ed378e1d08448897c99ab759ba840e.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animc8ed378e1d08448897c99ab759ba840e.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectc8ed378e1d08448897c99ab759ba840e" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c8ed378e1d08448897c99ab759ba840e"
#              >
#       <label for="_anim_radio1_c8ed378e1d08448897c99ab759ba840e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c8ed378e1d08448897c99ab759ba840e"
#              checked>
#       <label for="_anim_radio2_c8ed378e1d08448897c99ab759ba840e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c8ed378e1d08448897c99ab759ba840e"
#              >
#       <label for="_anim_radio3_c8ed378e1d08448897c99ab759ba840e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc8ed378e1d08448897c99ab759ba840e";
#     var slider_id = "_anim_sliderc8ed378e1d08448897c99ab759ba840e";
#     var loop_select_id = "_anim_loop_selectc8ed378e1d08448897c99ab759ba840e";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANBklEQVR4nO3cX2hXhf/H8ff8TW9ErfhO1E3RMdJt\
# Cm5O7KYLu1AR8WLuQjEIdQykC0W86a4rEyl0Zje78ULBXXSRoSSkEZV/kKUFIonQBm4aFKilU9bW\
# 53fxhfry05W/b81z3vp43A3PZ75w7jw553O2qkqlUgkASGZS0QMA4L8hYACkJGAApCRgAKQkYACk\
# JGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQk\
# YACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRg\
# AKRUXfQA/r6qqqqiJ/y/LFu27B//nF9//fU//jnhP1UqlaIn8H9UVXxV0ssWsIn4L5ft34B8nCrL\
# xy1EAFISMABSEjAAUhIwAFISs

# %%
train_model(model_drop, env, exp_replay, num_episodes=1000)
animation = create_animation(model_drop, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Episodes 0001-0010/1000 | Loss 0.0386 | Total Reward 2 | Change in Reward 2
# Episodes 0011-0020/1000 | Loss 0.0298 | Total Reward 6 | Change in Reward 4
# Episodes 0021-0030/1000 | Loss 0.0244 | Total Reward 4 | Change in Reward -2
# Episodes 0031-0040/1000 | Loss 0.0376 | Total Reward 6 | Change in Reward 2
# Episodes 0041-0050/1000 | Loss 0.0209 | Total Reward 2 | Change in Reward -4
# Episodes 0051-0060/1000 | Loss 0.0169 | Total Reward 2 | Change in Reward 0
# Episodes 0061-0070/1000 | Loss 0.0166 | Total Reward 8 | Change in Reward 6
# Episodes 0071-0080/1000 | Loss 0.0254 | Total Reward 4 | Change in Reward -4
# Episodes 0081-0090/1000 | Loss 0.0371 | Total Reward 2 | Change in Reward -2
# Episodes 0091-0100/1000 | Loss 0.0082 | Total Reward 2 | Change in Reward 0
# Episodes 0101-0110/1000 | Loss 0.0105 | Total Reward 2 | Change in Reward 0
# Episodes 0111-0120/1000 | Loss 0.0677 | Total Reward 0 | Change in Reward -2
# Episodes 0121-0130/1000 | Loss 0.0371 | Total Reward 2 | Change in Reward 2
# Episodes 0131-0140/1000 | Loss 0.0343 | Total Reward 4 | Change in Reward 2
# Episodes 0141-0150/1000 | Loss 0.0155 | Total Reward 2 | Change in Reward -2
# Episodes 0151-0160/1000 | Loss 0.0411 | Total Reward 4 | Change in Reward 2
# Episodes 0161-0170/1000 | Loss 0.0191 | Total Reward 8 | Change in Reward 4
# Episodes 0171-0180/1000 | Loss 0.0255 | Total Reward 8 | Change in Reward 0
# Episodes 0181-0190/1000 | Loss 0.0161 | Total Reward 8 | Change in Reward 0
# Episodes 0191-0200/1000 | Loss 0.0091 | Total Reward 8 | Change in Reward 0
# Episodes 0201-0210/1000 | Loss 0.0069 | Total Reward 10 | Change in Reward 2
# Episodes 0211-0220/1000 | Loss 0.0192 | Total Reward 8 | Change in Reward -2
# Episodes 0221-0230/1000 | Loss 0.0265 | Total Reward 8 | Change in Reward 0
# Episodes 0231-0240/1000 | Loss 0.0202 | Total Reward 6 | Change in Reward -2
# Episodes 0241-0250/1000 | Loss 0.0034 | Total Reward 4 | Change in Reward -2
# Episodes 0251-0260/1000 | Loss 0.0081 | Total Reward 10 | Change in Reward 6
# Episodes 0261-0270/1000 | Loss 0.0205 | Total Reward 4 | Change in Reward -6
# Episodes 0271-0280/1000 | Loss 0.0170 | Total Reward 8 | Change in Reward 4
# Episodes 0281-0290/1000 | Loss 0.0134 | Total Reward 6 | Change in Reward -2
# Episodes 0291-0300/1000 | Loss 0.0144 | Total Reward 2 | Change in Reward -4
# Episodes 0301-0310/1000 | Loss 0.0079 | Total Reward 6 | Change in Reward 4
# Episodes 0311-0320/1000 | Loss 0.0021 | Total Reward 10 | Change in Reward 4
# Episodes 0321-0330/1000 | Loss 0.0101 | Total Reward 8 | Change in Reward -2
# Episodes 0331-0340/1000 | Loss 0.0023 | Total Reward 10 | Change in Reward 2
# Episodes 0341-0350/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 0
# Episodes 0351-0360/1000 | Loss 0.0033 | Total Reward 10 | Change in Reward 0
# Episodes 0361-0370/1000 | Loss 0.0036 | Total Reward 10 | Change in Reward 0
# Episodes 0371-0380/1000 | Loss 0.0023 | Total Reward 10 | Change in Reward 0
# Episodes 0381-0390/1000 | Loss 0.0015 | Total Reward 10 | Change in Reward 0
# Episodes 0391-0400/1000 | Loss 0.0024 | Total Reward 8 | Change in Reward -2
# Episodes 0401-0410/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 2
# Episodes 0411-0420/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0421-0430/1000 | Loss 0.0009 | Total Reward 10 | Change in Reward 0
# Episodes 0431-0440/1000 | Loss 0.0246 | Total Reward 4 | Change in Reward -6
# Episodes 0441-0450/1000 | Loss 0.0036 | Total Reward 6 | Change in Reward 2
# Episodes 0451-0460/1000 | Loss 0.0320 | Total Reward 8 | Change in Reward 2
# Episodes 0461-0470/1000 | Loss 0.0233 | Total Reward 8 | Change in Reward 0
# Episodes 0471-0480/1000 | Loss 0.0096 | Total Reward 10 | Change in Reward 2
# Episodes 0481-0490/1000 | Loss 0.0035 | Total Reward 10 | Change in Reward 0
# Episodes 0491-0500/1000 | Loss 0.0017 | Total Reward 10 | Change in Reward 0
# Episodes 0501-0510/1000 | Loss 0.0016 | Total Reward 8 | Change in Reward -2
# Episodes 0511-0520/1000 | Loss 0.0013 | Total Reward 8 | Change in Reward 0
# Episodes 0521-0530/1000 | Loss 0.0025 | Total Reward 10 | Change in Reward 2
# Episodes 0531-0540/1000 | Loss 0.0026 | Total Reward 10 | Change in Reward 0
# Episodes 0541-0550/1000 | Loss 0.0016 | Total Reward 8 | Change in Reward -2
# Episodes 0551-0560/1000 | Loss 0.0030 | Total Reward 10 | Change in Reward 2
# Episodes 0561-0570/1000 | Loss 0.0022 | Total Reward 10 | Change in Reward 0
# Episodes 0571-0580/1000 | Loss 0.0013 | Total Reward 10 | Change in Reward 0
# Episodes 0581-0590/1000 | Loss 0.0016 | Total Reward 10 | Change in Reward 0
# Episodes 0591-0600/1000 | Loss 0.0013 | Total Reward 10 | Change in Reward 0
# Episodes 0601-0610/1000 | Loss 0.0007 | Total Reward 10 | Change in Reward 0
# Episodes 0611-0620/1000 | Loss 0.0007 | Total Reward 10 | Change in Reward 0
# Episodes 0621-0630/1000 | Loss 0.0007 | Total Reward 8 | Change in Reward -2
# Episodes 0631-0640/1000 | Loss 0.0006 | Total Reward 10 | Change in Reward 2
# Episodes 0641-0650/1000 | Loss 0.0012 | Total Reward 10 | Change in Reward 0
# Episodes 0651-0660/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0661-0670/1000 | Loss 0.0023 | Total Reward 8 | Change in Reward -2
# Episodes 0671-0680/1000 | Loss 0.0031 | Total Reward 8 | Change in Reward 0
# Episodes 0681-0690/1000 | Loss 0.0019 | Total Reward 10 | Change in Reward 2
# Episodes 0691-0700/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0701-0710/1000 | Loss 0.0016 | Total Reward 10 | Change in Reward 0
# Episodes 0711-0720/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0721-0730/1000 | Loss 0.0065 | Total Reward 10 | Change in Reward 0
# Episodes 0731-0740/1000 | Loss 0.0008 | Total Reward 8 | Change in Reward -2
# Episodes 0741-0750/1000 | Loss 0.0009 | Total Reward 10 | Change in Reward 2
# Episodes 0751-0760/1000 | Loss 0.0021 | Total Reward 10 | Change in Reward 0
# Episodes 0761-0770/1000 | Loss 0.0028 | Total Reward 10 | Change in Reward 0
# Episodes 0771-0780/1000 | Loss 0.0010 | Total Reward 8 | Change in Reward -2
# Episodes 0781-0790/1000 | Loss 0.0062 | Total Reward 10 | Change in Reward 2
# Episodes 0791-0800/1000 | Loss 0.0003 | Total Reward 10 | Change in Reward 0
# Episodes 0801-0810/1000 | Loss 0.0011 | Total Reward 10 | Change in Reward 0
# Episodes 0811-0820/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0821-0830/1000 | Loss 0.0038 | Total Reward 10 | Change in Reward 0
# Episodes 0831-0840/1000 | Loss 0.0038 | Total Reward 10 | Change in Reward 0
# Episodes 0841-0850/1000 | Loss 0.0008 | Total Reward 10 | Change in Reward 0
# Episodes 0851-0860/1000 | Loss 0.0006 | Total Reward 10 | Change in Reward 0
# Episodes 0861-0870/1000 | Loss 0.0004 | Total Reward 10 | Change in Reward 0
# Episodes 0871-0880/1000 | Loss 0.0006 | Total Reward 10 | Change in Reward 0
# Episodes 0881-0890/1000 | Loss 0.0004 | Total Reward 10 | Change in Reward 0
# Episodes 0891-0900/1000 | Loss 0.0009 | Total Reward 10 | Change in Reward 0
# Episodes 0901-0910/1000 | Loss 0.0005 | Total Reward 10 | Change in Reward 0
# Episodes 0911-0920/1000 | Loss 0.0007 | Total Reward 10 | Change in Reward 0
# Episodes 0921-0930/1000 | Loss 0.0004 | Total Reward 10 | Change in Reward 0
# Episodes 0931-0940/1000 | Loss 0.0007 | Total Reward 8 | Change in Reward -2
# Episodes 0941-0950/1000 | Loss 0.0005 | Total Reward 10 | Change in Reward 2
# Episodes 0951-0960/1000 | Loss 0.0157 | Total Reward 10 | Change in Reward 0
# Episodes 0961-0970/1000 | Loss 0.0006 | Total Reward 10 | Change in Reward 0
# Episodes 0971-0980/1000 | Loss 0.0003 | Total Reward 10 | Change in Reward 0
# Episodes 0981-0990/1000 | Loss 0.0004 | Total Reward 10 | Change in Reward 0
# Episodes 0991-1000/1000 | Loss 0.0005 | Total Reward 10 | Change in Reward 0
# Total Reward: 10
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6a2661689d39448c959af77d271cb359">
#   <div class="anim-controls">
#     <input id="_anim_slider6a2661689d39448c959af77d271cb359" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6a2661689d39448c959af77d271cb359.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim6a2661689d39448c959af77d271cb359.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim6a2661689d39448c959af77d271cb359.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select6a2661689d39448c959af77d271cb359" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6a2661689d39448c959af77d271cb359"
#              >
#       <label for="_anim_radio1_6a2661689d39448c959af77d271cb359">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6a2661689d39448c959af77d271cb359"
#              checked>
#       <label for="_anim_radio2_6a2661689d39448c959af77d271cb359">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6a2661689d39448c959af77d271cb359"
#              >
#       <label for="_anim_radio3_6a2661689d39448c959af77d271cb359">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6a2661689d39448c959af77d271cb359";
#     var slider_id = "_anim_slider6a2661689d39448c959af77d271cb359";
#     var loop_select_id = "_anim_loop_select6a2661689d39448c959af77d271cb359";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANC0lEQVR4nO3cX2hXhf/H8ff8TW9ErfhO1G2iIuk2\
# BfdH7KYLu1AR8UJ3oRiEOgbShSLedNeViRT+yW5244WCu+iihZKQRlT+QZYWiCRCG7hpUKCWTllb\
# n+/FD+rLT1f+vjXPebvH4254PvOFc+fJOZ+zVVUqlUoAQDKTih4AAP8NAQMgJQEDICUBAyAlAQMg\
# JQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAl\
# AQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUB\
# AyCl6qIH8PdVVVUVPeH/pbW19R//nF9//fU//jnhP1UqlaIn8H9UVXxV0ssWsPH4L5ft34B8nCrL\
# xy1EAFISMABSEjAAUhIwAFISs

# %%
#Game doesn't end until fruit drops
model_drop, env, exp_replay = build_model()
model_drop.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 20,503
# Trainable params: 20,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
animation = create_animation(model_drop, env, num_games=1)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Total Reward: -0.01
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbb55bde2df744aff9582b4d597b997d2">
#   <div class="anim-controls">
#     <input id="_anim_sliderbb55bde2df744aff9582b4d597b997d2" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbb55bde2df744aff9582b4d597b997d2.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animbb55bde2df744aff9582b4d597b997d2.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectbb55bde2df744aff9582b4d597b997d2" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bb55bde2df744aff9582b4d597b997d2"
#              >
#       <label for="_anim_radio1_bb55bde2df744aff9582b4d597b997d2">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bb55bde2df744aff9582b4d597b997d2"
#              checked>
#       <label for="_anim_radio2_bb55bde2df744aff9582b4d597b997d2">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bb55bde2df744aff9582b4d597b997d2"
#              >
#       <label for="_anim_radio3_bb55bde2df744aff9582b4d597b997d2">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbb55bde2df744aff9582b4d597b997d2";
#     var slider_id = "_anim_sliderbb55bde2df744aff9582b4d597b997d2";
#     var loop_select_id = "_anim_loop_selectbb55bde2df744aff9582b4d597b997d2";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANBUlEQVR4nO3cX2hXhf/H8ff8TW9ErfhO1G2iIuk2\
# BTcndtOFXaiIeKG7UAxCHQPpQhFvuuvKRAr/ZDe78ULBXXTRQklIIyr/IEsLRBKhDbZpUKCWTplb\
# n9/Fl+rHT1fy7bvOebvH4+6D56MvmDtPzvmcrapSqVQCAJKZVPQAAPhPCBgAKQkYACkJGAApCRgA\
# KQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAAp\
# CRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJ\
# GAApVRc9gL+vqqqq6AmUxPLly8fl7/3666/H5e/NpFKpFD2B/6eq4quSnoDxm/H6dvZ/TMDKyC1E\
# AFISMABSEjAAUhIwAFISsBI6c+

# %%
#I need better validation for this approach
#Needs improvement in the future, I can't even tell how many times the fruit gets caught

train_model(model_drop, env, exp_replay, num_episodes=750)
animation = create_animation(model_drop, env, num_games=1)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Episodes 0001-0010/0750 | Loss 0.0041 | Total Reward 5.0 | Change in Reward 5.0
# Episodes 0011-0020/0750 | Loss 0.0275 | Total Reward 4.99 | Change in Reward -0.009999999999999787
# Episodes 0021-0030/0750 | Loss 0.0014 | Total Reward 5.0 | Change in Reward 0.009999999999999787
# Episodes 0031-0040/0750 | Loss 0.0084 | Total Reward 4.98 | Change in Reward -0.019999999999999574
# Episodes 0041-0050/0750 | Loss 0.0035 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0051-0060/0750 | Loss 0.0015 | Total Reward 4.970000000000001 | Change in Reward -0.019999999999999574
# Episodes 0061-0070/0750 | Loss 0.0159 | Total Reward 5.99 | Change in Reward 1.0199999999999996
# Episodes 0071-0080/0750 | Loss 0.0257 | Total Reward 5.49 | Change in Reward -0.5
# Episodes 0081-0090/0750 | Loss 0.0074 | Total Reward 3.9800000000000004 | Change in Reward -1.5099999999999998
# Episodes 0091-0100/0750 | Loss 0.0110 | Total Reward 5.49 | Change in Reward 1.5099999999999998
# Episodes 0101-0110/0750 | Loss 0.0057 | Total Reward 5.49 | Change in Reward 0.0
# Episodes 0111-0120/0750 | Loss 0.0087 | Total Reward 4.0 | Change in Reward -1.4900000000000002
# Episodes 0121-0130/0750 | Loss 0.0018 | Total Reward 4.98 | Change in Reward 0.9800000000000004
# Episodes 0131-0140/0750 | Loss 0.0031 | Total Reward 4.98 | Change in Reward 0.0
# Episodes 0141-0150/0750 | Loss 0.0020 | Total Reward 4.98 | Change in Reward 0.0
# Episodes 0151-0160/0750 | Loss 0.0056 | Total Reward 5.48 | Change in Reward 0.5
# Episodes 0161-0170/0750 | Loss 0.0008 | Total Reward 4.470000000000001 | Change in Reward -1.0099999999999998
# Episodes 0171-0180/0750 | Loss 0.0035 | Total Reward 5.0 | Change in Reward 0.5299999999999994
# Episodes 0181-0190/0750 | Loss 0.0067 | Total Reward 4.99 | Change in Reward -0.009999999999999787
# Episodes 0191-0200/0750 | Loss 0.0017 | Total Reward 5.49 | Change in Reward 0.5
# Episodes 0201-0210/0750 | Loss 0.0007 | Total Reward 4.48 | Change in Reward -1.0099999999999998
# Episodes 0211-0220/0750 | Loss 0.0008 | Total Reward 4.99 | Change in Reward 0.5099999999999998
# Episodes 0221-0230/0750 | Loss 0.0009 | Total Reward 4.99 | Change in Reward 0.0
# Episodes 0231-0240/0750 | Loss 0.0013 | Total Reward 4.98 | Change in Reward -0.009999999999999787
# Episodes 0241-0250/0750 | Loss 0.0006 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0251-0260/0750 | Loss 0.0178 | Total Reward 4.98 | Change in Reward -0.009999999999999787
# Episodes 0261-0270/0750 | Loss 0.0005 | Total Reward 5.48 | Change in Reward 0.5
# Episodes 0271-0280/0750 | Loss 0.0158 | Total Reward 4.48 | Change in Reward -1.0
# Episodes 0281-0290/0750 | Loss 0.0012 | Total Reward 4.98 | Change in Reward 0.5
# Episodes 0291-0300/0750 | Loss 0.0084 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0301-0310/0750 | Loss 0.0083 | Total Reward 5.49 | Change in Reward 0.5
# Episodes 0311-0320/0750 | Loss 0.0036 | Total Reward 4.48 | Change in Reward -1.0099999999999998
# Episodes 0321-0330/0750 | Loss 0.0030 | Total Reward 5.0 | Change in Reward 0.5199999999999996
# Episodes 0331-0340/0750 | Loss 0.0015 | Total Reward 4.98 | Change in Reward -0.019999999999999574
# Episodes 0341-0350/0750 | Loss 0.0051 | Total Reward 5.48 | Change in Reward 0.5
# Episodes 0351-0360/0750 | Loss 0.0048 | Total Reward 5.49 | Change in Reward 0.009999999999999787
# Episodes 0361-0370/0750 | Loss 0.0076 | Total Reward 3.99 | Change in Reward -1.5
# Episodes 0371-0380/0750 | Loss 0.0070 | Total Reward 4.98 | Change in Reward 0.9900000000000002
# Episodes 0381-0390/0750 | Loss 0.0020 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0391-0400/0750 | Loss 0.0078 | Total Reward 6.5 | Change in Reward 1.5099999999999998
# Episodes 0401-0410/0750 | Loss 0.0281 | Total Reward 3.5 | Change in Reward -3.0
# Episodes 0411-0420/0750 | Loss 0.0076 | Total Reward 5.0 | Change in Reward 1.5
# Episodes 0421-0430/0750 | Loss 0.0033 | Total Reward 5.5 | Change in Reward 0.5
# Episodes 0431-0440/0750 | Loss 0.0035 | Total Reward 4.48 | Change in Reward -1.0199999999999996
# Episodes 0441-0450/0750 | Loss 0.0059 | Total Reward 4.98 | Change in Reward 0.5
# Episodes 0451-0460/0750 | Loss 0.0137 | Total Reward 4.970000000000001 | Change in Reward -0.009999999999999787
# Episodes 0461-0470/0750 | Loss 0.0073 | Total Reward 5.5 | Change in Reward 0.5299999999999994
# Episodes 0471-0480/0750 | Loss 0.0047 | Total Reward 4.99 | Change in Reward -0.5099999999999998
# Episodes 0481-0490/0750 | Loss 0.0020 | Total Reward 4.48 | Change in Reward -0.5099999999999998
# Episodes 0491-0500/0750 | Loss 0.0108 | Total Reward 4.99 | Change in Reward 0.5099999999999998
# Episodes 0501-0510/0750 | Loss 0.0069 | Total Reward 4.98 | Change in Reward -0.009999999999999787
# Episodes 0511-0520/0750 | Loss 0.0048 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0521-0530/0750 | Loss 0.0197 | Total Reward 5.5 | Change in Reward 0.5099999999999998
# Episodes 0531-0540/0750 | Loss 0.0122 | Total Reward 4.98 | Change in Reward -0.5199999999999996
# Episodes 0541-0550/0750 | Loss 0.0039 | Total Reward 4.49 | Change in Reward -0.4900000000000002
# Episodes 0551-0560/0750 | Loss 0.0094 | Total Reward 4.99 | Change in Reward 0.5
# Episodes 0561-0570/0750 | Loss 0.0013 | Total Reward 4.98 | Change in Reward -0.009999999999999787
# Episodes 0571-0580/0750 | Loss 0.0052 | Total Reward 4.99 | Change in Reward 0.009999999999999787
# Episodes 0581-0590/0750 | Loss 0.0008 | Total Reward 5.0 | Change in Reward 0.009999999999999787
# Episodes 0591-0600/0750 | Loss 0.0010 | Total Reward 4.99 | Change in Reward -0.009999999999999787
# Episodes 0601-0610/0750 | Loss 0.0082 | Total Reward 4.99 | Change in Reward 0.0
# Episodes 0611-0620/0750 | Loss 0.0109 | Total Reward 4.970000000000001 | Change in Reward -0.019999999999999574
# Episodes 0621-0630/0750 | Loss 0.0017 | Total Reward 5.0 | Change in Reward 0.02999999999999936
# Episodes 0631-0640/0750 | Loss 0.0042 | Total Reward 4.98 | Change in Reward -0.019999999999999574
# Episodes 0641-0650/0750 | Loss 0.0067 | Total Reward 5.48 | Change in Reward 0.5
# Episodes 0651-0660/0750 | Loss 0.0035 | Total Reward 4.460000000000001 | Change in Reward -1.0199999999999996
# Episodes 0661-0670/0750 | Loss 0.0017 | Total Reward 5.0 | Change in Reward 0.5399999999999991
# Episodes 0671-0680/0750 | Loss 0.0025 | Total Reward 4.98 | Change in Reward -0.019999999999999574
# Episodes 0681-0690/0750 | Loss 0.0014 | Total Reward 5.0 | Change in Reward 0.019999999999999574
# Episodes 0691-0700/0750 | Loss 0.0071 | Total Reward 5.49 | Change in Reward 0.4900000000000002
# Episodes 0701-0710/0750 | Loss 0.0015 | Total Reward 4.470000000000001 | Change in Reward -1.0199999999999996
# Episodes 0711-0720/0750 | Loss 0.0008 | Total Reward 5.49 | Change in Reward 1.0199999999999996
# Episodes 0721-0730/0750 | Loss 0.0006 | Total Reward 4.98 | Change in Reward -0.5099999999999998
# Episodes 0731-0740/0750 | Loss 0.0009 | Total Reward 4.49 | Change in Reward -0.4900000000000002
# Episodes 0741-0750/0750 | Loss 0.0031 | Total Reward 5.0 | Change in Reward 0.5099999999999998
# Total Reward: 0.5
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb4a2e250a27c4504ba9ae90eef315b71">
#   <div class="anim-controls">
#     <input id="_anim_sliderb4a2e250a27c4504ba9ae90eef315b71" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb4a2e250a27c4504ba9ae90eef315b71.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animb4a2e250a27c4504ba9ae90eef315b71.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectb4a2e250a27c4504ba9ae90eef315b71" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b4a2e250a27c4504ba9ae90eef315b71"
#              >
#       <label for="_anim_radio1_b4a2e250a27c4504ba9ae90eef315b71">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b4a2e250a27c4504ba9ae90eef315b71"
#              checked>
#       <label for="_anim_radio2_b4a2e250a27c4504ba9ae90eef315b71">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b4a2e250a27c4504ba9ae90eef315b71"
#              >
#       <label for="_anim_radio3_b4a2e250a27c4504ba9ae90eef315b71">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb4a2e250a27c4504ba9ae90eef315b71";
#     var slider_id = "_anim_sliderb4a2e250a27c4504ba9ae90eef315b71";
#     var loop_select_id = "_anim_loop_selectb4a2e250a27c4504ba9ae90eef315b71";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAANAUlEQVR4nO3cX2iXdf/H8ff8TU9ErWiiboqKpNsU\
# 3B9ZJx3YgYqIB7oDxSDUMZAOFPGks45MpPBPdrITDxTcQQcZSkIaUfkHWVogkghtsE2DArV0ytz6\
# 3gc3v/rx05Xc3eu63u7xOBtd33qR+HlyXd9LqyqVSiUAIJlJRQ8AgP+EgAGQkoABkJKAAZCSgAGQ\
# koABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCS\
# gAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKAAZCSgAGQkoABkJKA\
# AZBSddED+PuqqqqKnlC4lpaWcfn3fvPNN+Py7yWfSqVS9AT+n6qKX5X0BGz8Dhf/b/lfjsry8QgR\
# gJQEDICUBAyAlAQMgJQErITOnD
